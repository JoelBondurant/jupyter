// %% [markdown]
// # Max Squeeze
// ## 11 Dimensional Random Matrices
// ---

// %%
:dep ndarray
:dep ndarray-linalg = { version = "*", features = ["openblas-system"] }

// %%
use ndarray::{Array, Array2};
use ndarray_linalg::{random, Determinant};

// %%
:dep plotters = { default_features = false, features = ["evcxr", "all_series", "all_elements"] }

// %%
use plotters::prelude::*;

// %%
let max_dimension = 24usize;
let samples = 1_000_000usize;
let mut dets = Vec::<Vec<f64>>::with_capacity(max_dimension - 2);
for n in (2..max_dimension+1) {
    dets.push(Vec::<f64>::with_capacity(samples));
    for k in (0..samples) {
        let m: Array2<f64> = random((n,n));
        dets[n-2].push(m.det().unwrap());
    }
}
// Out:
// ()

// %%
evcxr_figure((1200, 600), |root| {
    let margin = 100;
    let root = root.margin(margin, margin, margin, margin);
    root.fill(&WHITE);
    let mut chart = ChartBuilder::on(&root)
        .caption("Max Squeeze", ("sans serif", 20).into_font())
        .x_label_area_size(50)
        .y_label_area_size(50)
        .build_cartesian_2d(1f32..(max_dimension as f32), -1f32..1f32)?;
    
    let x = Array::range(1., max_dimension as f32 + 1., 1.);

    chart.configure_mesh()
        .x_desc("Dimension")
        .y_desc("Determinant")
        .draw()?;

    for n in (2..max_dimension) {
        let quartiles = Quartiles::new(&dets[n-2]);
        chart.draw_series(x.map(|x| {
            Boxplot::new_vertical(n as f32, &quartiles)
        }))?;
    }

    Ok(())
}).style("width: 100%")
// Out:
// <div style="width: 100%"><svg width="1200" height="600" viewBox="0 0 1200 600" xmlns="http://www.w3.org/2000/svg">
// <rect x="100" y="100" width="1000" height="400" opacity="1" fill="#FFFFFF" stroke="none"/>
// <text x="600" y="105" dy="0.76em" text-anchor="middle" font-family="sans serif" font-size="16.129032258064516" opacity="1" fill="#000000">
// Max Squeeze
// </text>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="150" y1="449" x2="150" y2="126"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="170" y1="449" x2="170" y2="126"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="191" y1="449" x2="191" y2="126"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="211" y1="449" x2="211" y2="126"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="232" y1="449" x2="232" y2="126"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="253" y1="449" x2="253" y2="126"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="273" y1="449" x2="273" y2="126"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="294" y1="449" x2="294" y2="126"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="315" y1="449" x2="315" y2="126"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="335" y1="449" x2="335" y2="126"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="356" y1="449" x2="356" y2="126"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="376" y1="449" x2="376" y2="126"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="397" y1="449" x2="397" y2="126"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="418" y1="449" x2="418" y2="126"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="438" y1="449" x2="438" y2="126"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="459" y1="449" x2="459" y2="126"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="480" y1="449" x2="480" y2="126"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="500" y1="449" x2="500" y2="126"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="521" y1="449" x2="521" y2="126"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="541" y1="449" x2="541" y2="126"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="562" y1="449" x2="562" y2="126"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="583" y1="449" x2="583" y2="126"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="603" y1="449" x2="603" y2="126"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="624" y1="449" x2="624" y2="126"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="645" y1="449" x2="645" y2="126"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="665" y1="449" x2="665" y2="126"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="686" y1="449" x2="686" y2="126"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="707" y1="449" x2="707" y2="126"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="727" y1="449" x2="727" y2="126"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="748" y1="449" x2="748" y2="126"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="768" y1="449" x2="768" y2="126"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="789" y1="449" x2="789" y2="126"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="810" y1="449" x2="810" y2="126"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="830" y1="449" x2="830" y2="126"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="851" y1="449" x2="851" y2="126"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="872" y1="449" x2="872" y2="126"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="892" y1="449" x2="892" y2="126"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="913" y1="449" x2="913" y2="126"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="933" y1="449" x2="933" y2="126"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="954" y1="449" x2="954" y2="126"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="975" y1="449" x2="975" y2="126"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="995" y1="449" x2="995" y2="126"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="1016" y1="449" x2="1016" y2="126"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="1037" y1="449" x2="1037" y2="126"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="1057" y1="449" x2="1057" y2="126"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="1078" y1="449" x2="1078" y2="126"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="1099" y1="449" x2="1099" y2="126"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="150" y1="449" x2="1099" y2="449"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="150" y1="446" x2="1099" y2="446"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="150" y1="443" x2="1099" y2="443"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="150" y1="440" x2="1099" y2="440"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="150" y1="437" x2="1099" y2="437"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="150" y1="433" x2="1099" y2="433"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="150" y1="430" x2="1099" y2="430"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="150" y1="427" x2="1099" y2="427"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="150" y1="424" x2="1099" y2="424"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="150" y1="420" x2="1099" y2="420"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="150" y1="417" x2="1099" y2="417"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="150" y1="414" x2="1099" y2="414"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="150" y1="411" x2="1099" y2="411"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="150" y1="408" x2="1099" y2="408"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="150" y1="404" x2="1099" y2="404"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="150" y1="401" x2="1099" y2="401"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="150" y1="398" x2="1099" y2="398"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="150" y1="395" x2="1099" y2="395"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="150" y1="391" x2="1099" y2="391"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="150" y1="388" x2="1099" y2="388"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="150" y1="385" x2="1099" y2="385"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="150" y1="382" x2="1099" y2="382"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="150" y1="378" x2="1099" y2="378"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="150" y1="375" x2="1099" y2="375"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="150" y1="372" x2="1099" y2="372"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="150" y1="369" x2="1099" y2="369"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="150" y1="366" x2="1099" y2="366"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="150" y1="362" x2="1099" y2="362"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="150" y1="359" x2="1099" y2="359"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="150" y1="356" x2="1099" y2="356"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="150" y1="353" x2="1099" y2="353"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="150" y1="349" x2="1099" y2="349"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="150" y1="346" x2="1099" y2="346"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="150" y1="343" x2="1099" y2="343"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="150" y1="340" x2="1099" y2="340"/>
// <line opacity="0.1" stroke="#000000" stroke-wi
