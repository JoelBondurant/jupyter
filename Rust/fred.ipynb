// %% [markdown]
// # FRED:
// ---

// %%
:cache 1000
:dep chrono
:dep plotters = { default_features = false, features = ["evcxr", "all_series", "datetime"] }
:dep reqwest = { features = ["blocking"] }
use chrono::prelude::*;
use plotters::prelude::*;
// Out:
// cache: 1000 MiB

// %%
let url = "https://fred.stlouisfed.org/graph/fredgraph.csv?id=RESPPLLOPNWW";
let csv_txt = reqwest::blocking::get(url)?.text()?;

// %%
let csv_data = csv_txt.split("\n").map(|x| {
    x.split(",").map(|x| x.to_owned()).collect::<Vec<_>>()
}).filter(|x| x.len() == 2).collect::<Vec<_>>();

// %%
let data = csv_data[1..].iter().map(|x| 
    (x[0].parse::<NaiveDate>().unwrap(), x[1].parse::<f32>().unwrap().floor() as i32)
).collect::<Vec<_>>();

// %%
evcxr_figure((840, 420), |root| {
    root.fill(&WHITE)?;
    let start_date = "2010-12-01".parse::<NaiveDate>().unwrap();
    let end_date = "2024-12-01".parse::<NaiveDate>().unwrap();
    let mut chart = ChartBuilder::on(&root)
        .caption("FED Liabilities: Fiatios Metric", ("sans-serif", 20))
        .set_label_area_size(LabelAreaPosition::Left, 60)
        .set_label_area_size(LabelAreaPosition::Bottom, 30)
        .build_cartesian_2d(start_date..end_date, -120000..6000)?;
    chart.configure_mesh().draw()?;
    chart.draw_series(LineSeries::new(data.clone(), ShapeStyle {
        color: RGBAColor(0, 80, 200, 8.0), filled: false, stroke_width: 2 }))?;
    Ok(())
})
// Out:
// <div style=""><svg width="840" height="420" viewBox="0 0 840 420" xmlns="http://www.w3.org/2000/svg">
// <rect x="0" y="0" width="840" height="420" opacity="1" fill="#FFFFFF" stroke="none"/>
// <text x="420" y="5" dy="0.76em" text-anchor="middle" font-family="sans-serif" font-size="16.129032258064516" opacity="1" fill="#000000">
// FED Liabilities: Fiatios Metric
// </text>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="60" y1="389" x2="60" y2="26"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="67" y1="389" x2="67" y2="26"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="74" y1="389" x2="74" y2="26"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="82" y1="389" x2="82" y2="26"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="89" y1="389" x2="89" y2="26"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="97" y1="389" x2="97" y2="26"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="104" y1="389" x2="104" y2="26"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="112" y1="389" x2="112" y2="26"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="119" y1="389" x2="119" y2="26"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="127" y1="389" x2="127" y2="26"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="134" y1="389" x2="134" y2="26"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="142" y1="389" x2="142" y2="26"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="149" y1="389" x2="149" y2="26"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="157" y1="389" x2="157" y2="26"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="164" y1="389" x2="164" y2="26"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="171" y1="389" x2="171" y2="26"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="179" y1="389" x2="179" y2="26"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="186" y1="389" x2="186" y2="26"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="194" y1="389" x2="194" y2="26"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="201" y1="389" x2="201" y2="26"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="209" y1="389" x2="209" y2="26"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="216" y1="389" x2="216" y2="26"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="224" y1="389" x2="224" y2="26"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="231" y1="389" x2="231" y2="26"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="239" y1="389" x2="239" y2="26"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="246" y1="389" x2="246" y2="26"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="254" y1="389" x2="254" y2="26"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="261" y1="389" x2="261" y2="26"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="268" y1="389" x2="268" y2="26"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="276" y1="389" x2="276" y2="26"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="283" y1="389" x2="283" y2="26"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="291" y1="389" x2="291" y2="26"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="298" y1="389" x2="298" y2="26"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="306" y1="389" x2="306" y2="26"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="313" y1="389" x2="313" y2="26"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="321" y1="389" x2="321" y2="26"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="328" y1="389" x2="328" y2="26"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="336" y1="389" x2="336" y2="26"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="343" y1="389" x2="343" y2="26"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="351" y1="389" x2="351" y2="26"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="358" y1="389" x2="358" y2="26"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="366" y1="389" x2="366" y2="26"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="373" y1="389" x2="373" y2="26"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="380" y1="389" x2="380" y2="26"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="388" y1="389" x2="388" y2="26"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="395" y1="389" x2="395" y2="26"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="403" y1="389" x2="403" y2="26"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="410" y1="389" x2="410" y2="26"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="418" y1="389" x2="418" y2="26"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="425" y1="389" x2="425" y2="26"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="433" y1="389" x2="433" y2="26"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="440" y1="389" x2="440" y2="26"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="448" y1="389" x2="448" y2="26"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="455" y1="389" x2="455" y2="26"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="463" y1="389" x2="463" y2="26"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="470" y1="389" x2="470" y2="26"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="477" y1="389" x2="477" y2="26"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="485" y1="389" x2="485" y2="26"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="492" y1="389" x2="492" y2="26"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="500" y1="389" x2="500" y2="26"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="507" y1="389" x2="507" y2="26"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="515" y1="389" x2="515" y2="26"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="522" y1="389" x2="522" y2="26"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="530" y1="389" x2="530" y2="26"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="537" y1="389" x2="537" y2="26"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="545" y1="389" x2="545" y2="26"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="552" y1="389" x2="552" y2="26"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="560" y1="389" x2="560" y2="26"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="567" y1="389" x2="567" y2="26"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="575" y1="389" x2="575" y2="26"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="582" y1="389" x2="582" y2="26"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="589" y1="389" x2="589" y2="26"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="597" y1="389" x2="597" y2="26"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="604" y1="389" x2="604" y2="26"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="612" y1="389" x2="612" y2="26"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="619" y1="389" x2="619" y2="26"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="627" y1="389" x2="627" y2="26"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="634" y1="389" x2="634" y2="26"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="642" y1="389" x2="642" y2="26"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="649" y1="389" x2="649" y2="26"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="657" y1="389" x2="657" y2="26"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="664" y1="389" x2="664" y2="26"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="672" y1="389" x2="672" y2="26"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="679" y1="389" x2="679" y2="26"/>
// <li
