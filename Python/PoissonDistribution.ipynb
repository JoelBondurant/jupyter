# %%
import math
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x = np.linspace(0, 10, 10**3)
def y(k):
    return np.power(x, k) * np.exp(-x) / math.factorial(k)

# %%
for i in range(6): plt.plot(x, y(i))
