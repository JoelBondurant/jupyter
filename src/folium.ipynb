# %%
import json
import numpy as np
import pandas as pd
import folium, folium.plugins

# %%
SF = (37.75, -122.25)

# %%
amap = folium.Map(location=SF, tiles='Stamen Toner', zoom_start=9)
amap.add_children(folium.LatLngPopup())
dat = (np.random.normal(size=(200,2))*np.array([[0.5,0.5]])+np.array([SF])).tolist()
amap.add_children(folium.plugins.HeatMap(dat))
amap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;"></iframe></div></div>

# %%
folium.__version__
# Out:
# '0.2.1'
